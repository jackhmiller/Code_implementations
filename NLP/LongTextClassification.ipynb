# %%
import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import LabelEncoder
import string
import re
import matplotlib.pyplot as plt
import itertools
from transformers import AutoTokenizer, AutoModel, AutoModelForTokenClassification, pipeline,BertTokenizer, BertModel
import spacy
spcy = spacy.load("en_core_web_sm")
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from bertopic import BERTopic
import torch
import torch.nn as nn
import torch.functional as f
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.linear_model import LogisticRegression
# %matplotlib inline

# %%
dataset.to_parquet("legal_cases.parquet")

# %%
dataset = pd.read_parquet("legal_cases.parquet")

# %%
dataset.head()
# Out:
#                      id                                               text  \
# 0  r-e4EYcBD5gMZwcz41zP  UNITED STATES DISTRICT COURT \nEASTERN DISTRIC...
# 1  i9H5DocBD5gMZwcztj0y  IN THE UNITED STATES DISTRICT COURT \nFOR THE ...
# 2  SMn3DYcBD5gMZwcz-hwH  IN THE UNITED STATES DISTRICT COURT\n FOR THE ...
# 3  GMIWDYcBD5gMZwczDQBb  Case No. _______________ \n \n \nCLASS ACTION ...
# 4  lELw_IgBF5pVm5zYONwC  UNITED STATES DISTRICT COURT \n SOUTHERN DISTR...
#
#                    domain                                         clean_text
# 0          consumer fraud  united states district court eastern district ...
# 1                 privacy  in the united states district court for the di...
# 2                 privacy  in the united states district court for the we...
# 3  criminal & enforcement  case no class action complaint for violations ...
# 4          consumer fraud  united states district court southern district...

# %% [markdown]
# Clean Text

# %%
def run_preprocessing(text):
    text = preprocess(text)
    text = remove_stopwords(text)
    # text = lemmatizing(text)
    # text = remove_double_words(text)
    return text

def preprocess(text):
    text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text)
    text = text.lower()
    text = text.strip()
    text = re.compile('<.*?>').sub('', text)
    text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)
    text = re.sub('\s+', ' ', text)
    text = re.sub(r'\[[0-9]*\]', ' ', text)  # [0-9]
    text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
    text = re.sub(r'\d', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text

def remove_stopwords(text):
    chars = [i for i in text.split() if i not in stopwords.words('english') and len(i) > 2]
    return ' '.join(chars)

def remove_double_words(text):
    return ' '.join(list(set([i for i in text.split(' ')])))

def lemmatizing(text):
    lemmatizer = WordNetLemmatizer()
    words = nltk.word_tokenize(text)
    chars = [lemmatizer.lemmatize(word) for word in words]

    return " ".join(chars)

# %%
dataset['clean_text'] = dataset['text'].apply(run_preprocessing)

# %%
def get_most_common_words(df, threshold=0.8):
    row_thresh_count = threshold * len(df)
    row_count = Counter()
    for i, row in df.iterrows():
        words = set(re.findall(r"\w+", row['clean_text']))
        row_count.update(words)

    return [word for word, count in row_count.items() if count >= row_thresh_count]

# %%
common_words = get_most_common_words(dataset)

# %%
def remove_common_words(common_words, text):
    words = text.split()
    filtered_words = [word for word in words if word not in common_words]
    return " ".join(filtered_words)

# %%
dataset['clean_text'] = dataset['clean_text'].apply(lambda x: remove_common_words(common_words, x))

# %%
def remove_entities(text, entity_types=['GPE', 'DATE', 'ORDINAL', 'PERSON']):
    doc = spcy(text)
    unique_ents = []
    for ent in doc.ents:
        if str(ent) in unique_ents:
            pass
        else:
            if ent.label_ in entity_types:
                unique_ents.append(str(ent))    
    
    words = text.split()
    filtered_words = [word for word in words if word not in unique_ents]
    return " ".join(filtered_words)

# %% [markdown]
# Encode Labels

# %%
le = LabelEncoder()
dataset['label'] = le.fit_transform(dataset['domain'])
label_mapping = dict(zip(range(len(le.classes_)), le.classes_))

# %% [markdown]
# ## Topic Modeling

# %%
empty_dimensionality_model = BaseDimensionalityReduction()
clf = LogisticRegression()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# %%
topic_model= BERTopic(
        umap_model=empty_dimensionality_model,
        hdbscan_model=clf,
        ctfidf_model=ctfidf_model
)
topics, probs = topic_model.fit_transform(dataset['clean_text'].values, y=dataset['label'].values)

# %%
mappings = topic_model.topic_mapper_.get_mappings()
mapping = {value: label_mapping[mappings[value]] for value in mappings.keys()}

# %%
df = topic_model.get_topic_info()
df["Class"] = df.Topic.map(mapping)

# %%
df
# Out:
#     Topic  Count                                     Name  \
# 0      -1    299             -1_plan_services_new_contact
# 1       0    144  0_company_companys_statements_financial
# 2       1     87          1_website_blind_access_services
# 3       2     68              2_market_prices_apple_price
# 4       3     63           3_debt_collection_letter_fdcpa
# 5       4     55                4_generic_drug_patent_fda
# 6       5     49                  5_hours_pay_york_worked
# 7       6     44          6_telephone_detail_garage_smart
# 8       7     41              7_flsa_texas_overtime_hours
# 9       8     33              8_telephone_calls_tcpa_text
# 10      9     29               9_data_security_breach_pii
# 11     10     29              10_credit_sierra_pacific_mp
# 12     11     28     11_debt_collection_florida_mcdonalds
# 13     12     27     12_ada_accessible_franchisees_rights
# 14     13     23  13_fax_faxes_unsolicited_advertisements
# 15     14     23         14_telephone_calls_cellular_tcpa
# 16     15     21             15_blind_website_access_york
# 17     16     20   16_employees_illinois_leave_volkswagen
# 18     17     19           17_tecfidera_biogen_pml_asylum
# 19     18     18       18_debt_collection_fdcpa_collector
# 20     19     17             19_telephone_calls_text_tcpa
# 21     20     16              20_flsa_overtime_ms_georgia
# 22     21     14            21_flsa_collective_hours_york
# 23     22     13          22_plan_upmc_erisa_participants
# 24     23     13              23_sitel_wages_pay_williams
# 25     24     11              24_ohio_flsa_wage_employees
#
#                                        Representation  \
# 0   [plan, services, new, contact, telephone, heal...
# 1   [company, companys, statements, financial, sec...
# 2   [website, blind, access, services, visuallyimp...
# 3   [market, prices, apple, price, facebook, produ...
# 4   [debt, collection, letter, fdcpa, consumer, co...
# 5   [generic, drug, patent, fda, market, vascepa, ...
# 6   [hours, pay, york, worked, new, nyll, flsa, em...
# 7   [telephone, detail, garage, smart, calls, cali...
# 8   [flsa, texas, overtime, hours, worked, pay, em...
# 9   [telephone, calls, tcpa, text, messages, cellu...
# 10  [data, security, breach, pii, personal, identi...
# 11  [credit, sierra, pacific, mp, loan, star, atg,...
# 12  [debt, collection, florida, mcdonalds, pounder...
# 13  [ada, accessible, franchisees, rights, facilit...
# 14  [fax, faxes, unsolicited, advertisements, send...
# 15  [telephone, calls, cellular, tcpa, call, numbe...
# 16  [blind, website, access, york, deaf, ny, right...
# 17  [employees, illinois, leave, volkswagen, imwl,...
# 18  [tecfidera, biogen, pml, asylum, us, service, ...
# 19  [debt, collection, fdcpa, collector, messages,...
# 20  [telephone, calls, text, tcpa, message, messag...
# 21  [flsa, overtime, ms, georgia, hours, urban, em...
# 22  [flsa, collective, hours, york, new, employmen...
# 23  [plan, upmc, erisa, participants, plans, highm...
# 24  [sitel, wages, pay, williams, wage, flsa, over...
# 25  [ohio, flsa, wage, employees, minimum, osu, co...
#
#                                   Representative_Docs  \
# 0   [john p kristensen sbn david l weisberg sbn kr...
# 1   [southern new york andre brodeur individually ...
# 2   [southern new york x shael cruz demand embrace...
# 3   [maine portland huntalpine club llc demanded m...
# 4   [eastern new york ouriel ezra demand fh cann a...
# 5   [eastern virginia alexandria division louisian...
# 6   [southern new york x jose taveras collective v...
# 7   [todd friedman sbn meghan george sbn adrian r ...
# 8   [southern texas corpus christi division cassan...
# 9   [offices ronald marron ronald marron sbn ronco...
# 10  [middle tennessee j paul mchenry individually ...
# 11  [northern illinois eastern division garner pro...
# 12  [middle florida jaron finklea demanded credenc...
# 13  [michael grinblat offices michael grinblat bro...
# 14  [courtfor northern illinoiseastern division be...
# 15  [western north carolina charlotte division cur...
# 16  [cv shaked group pc dan shaked ds harwood suit...
# 17  [northern illinois eastern division antonio ma...
# 18  [date forofficeuseonlv judge docket number ore...
# 19  [filedin clerks cemar plaintiffglasser jagains...
# 20  [southern florida katiria ramos individually d...
# 21  [northern georgia atlanta division darrick jon...
# 22  [lee group pllc ck lee cl anne seelig east th ...
# 23  [minnesota janet smith debra thorne sonja lind...
# 24  [southern florida west palm beach division enr...
# 25  [northern ohio eastern division natalie kelly ...
#
#                                     Class
# 0                                     NaN
# 1                      employment & labor
# 2                          discrimination
# 3                               antitrust
# 4   intellectual property & communication
# 5                              healthcare
# 6                  criminal & enforcement
# 7                              securities
# 8                                 privacy
# 9        products liability and mass tort
# 10      civil rights, immigration, family
# 11      environmental & natural resources
# 12                         consumer fraud
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN

# %%
topic_model = BERTopic()
topics, _ = topic_model.fit_transform(dataset['clean_text'].values)
dataset['topics'] = topic_model.get_document_info(dataset['clean_text'].values)['Representation']

# %%
topic_model.get_document_info(dataset['clean_text'].values)
# Out:
#                                                Document  Topic  \
# 0     eastern new york chaya r denciger individually...      3
# 1     kansas george jones ad astra recovery services...      8
# 2     western pennsylvania pittsburgh division mark ...     -1
# 3     racketeer influenced corrupt organizations ohi...     -1
# 4     southern new york cv bobby phillips individual...     -1
# ...                                                 ...    ...
# 1199  lee cirsch ca bar lanier firm pc wilshire blvd...      2
# 1200  southern florida shawn moore demanded alliance...     11
# 1201  new mexico gerald davis jr individually collec...      7
# 1202  colorado x david katt anb bank injunctive decl...      1
# 1203  northern georgia atlanta division michael mene...     20
#
#                                       Name  \
# 0           3_debt_collection_letter_fdcpa
# 1              8_telephone_calls_tcpa_text
# 2             -1_plan_services_new_contact
# 3             -1_plan_services_new_contact
# 4             -1_plan_services_new_contact
# ...                                    ...
# 1199           2_market_prices_apple_price
# 1200  11_debt_collection_florida_mcdonalds
# 1201           7_flsa_texas_overtime_hours
# 1202       1_website_blind_access_services
# 1203           20_flsa_overtime_ms_georgia
#
#                                          Representation  \
# 0     [debt, collection, letter, fdcpa, consumer, co...
# 1     [telephone, calls, tcpa, text, messages, cellu...
# 2     [plan, services, new, contact, telephone, heal...
# 3     [plan, services, new, contact, telephone, heal...
# 4     [plan, services, new, contact, telephone, heal...
# ...                                                 ...
# 1199  [market, prices, apple, price, facebook, produ...
# 1200  [debt, collection, florida, mcdonalds, pounder...
# 1201  [flsa, texas, overtime, hours, worked, pay, em...
# 1202  [website, blind, access, services, visuallyimp...
# 1203  [flsa, overtime, ms, georgia, hours, urban, em...
#
#                                     Representative_Docs  \
# 0     [eastern new york ouriel ezra demand fh cann a...
# 1     [offices ronald marron ronald marron sbn ronco...
# 2     [john p kristensen sbn david l weisberg sbn kr...
# 3     [john p kristensen sbn david l weisberg sbn kr...
# 4     [john p kristensen sbn david l weisberg sbn kr...
# ...                                                 ...
# 1199  [maine portland huntalpine club llc demanded m...
# 1200  [middle florida jaron finklea demanded credenc...
# 1201  [southern texas corpus christi division cassan...
# 1202  [southern new york x shael cruz demand embrace...
# 1203  [northern georgia atlanta division darrick jon...
#
#                                             Top_n_words  Probability  \
# 0     debt - collection - letter - fdcpa - consumer ...     1.000000
# 1     telephone - calls - tcpa - text - messages - c...     0.569314
# 2     plan - services - new - contact - telephone - ...     0.000000
# 3     plan - services - new - contact - telephone - ...     0.000000
# 4     plan - services - new - contact - telephone - ...     0.000000
# ...                                                 ...          ...
# 1199  market - prices - apple - price - facebook - p...     0.803713
# 1200  debt - collection - florida - mcdonalds - poun...     0.949810
# 1201  flsa - texas - overtime - hours - worked - pay...     0.409937
# 1202  website - blind - access - services - visually...     0.497660
# 1203  flsa - overtime - ms - georgia - hours - urban...     1.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 1199                    False
# 1200                     True
# 1201                    False
# 1202                    False
# 1203                    False
#
# [1204 rows x 8 columns]

# %% [markdown]
# ____________

# %%
word_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
vectorization_model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
tokens = dataset['clean_text'].apply(lambda x: word_tokenize(x)[-500:])

# %%
data = [" ".join(i) for i in tokens]

# %%
inputs = word_tokenizer(data,
                        padding=True,
                        truncation=True,
                        return_tensors='pt')

with torch.no_grad():
    output = vectorization_model(**inputs)
    
embedding = output.last_hidden_state

# %%
def mean_pooling(embeddings, attention_mask):
    token_embeddings = embeddings[0]
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

# %%
embeddings = mean_pooling(output, inputs["attention_mask"])

# %%
embeddings.shape
# Out:
# torch.Size([1204, 768])

# %%
dataset['embedding'] = [i.numpy().tolist() for i in embeddings]

# %%
import pickle
file_path = 'dataset.pkl'
with open(file_path, 'wb') as f:
    pickle.dump(dataset, f)

# %%
labels = torch.tensor(dataset['label'].values)

# %% [markdown]
# ____________

# %%
class CNNModel(nn.Module):
    def __init__(self, embedding_size, hidden_size, num_classes):
        super(CNNModel, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(1, hidden_size, kernel_size=3, padding=1, stride=2),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Conv1d(hidden_size, hidden_size, kernel_size=3, padding=1, stride=2),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.AdaptiveMaxPool1d(1),
            nn.Flatten()
            )
        
        self.classifier_head = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        x = self.cnn(x)
        x = self.classifier_head(x)
        return x

# %%
def train(model, train_loader, optimizer, criterion):
    batch_losses = []
    for idx, batch in enumerate(train_loader):
        optimizer.zero_grad()
        inpt = batch['embedding'].unsqueeze(1)
        output = model(inpt)
        loss = criterion(output, batch['label'])
        batch_losses.append(loss)
        loss.backward()
        optimizer.step()
        
    return batch_losses

# %%
class EmbeddingDataset(Dataset):
    def __init__(self, embedding, labels):
        self.embedding = embedding
        self.labels = labels
        
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        label = self.labels[idx]
        embed = self.embedding[idx]
        return {'label': label, 'embedding': embed}

# %%
dset = EmbeddingDataset(embedding=embeddings,
                          labels=labels)

# %%
loader = DataLoader(dataset=dset, batch_size=32, shuffle=True)

# %%
embeddings.shape
# Out:
# torch.Size([1204, 768])

# %%
model = CNNModel(embedding_size=768,
                hidden_size=50,
                num_classes=12)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.1)

# %%
current_loss = 0
current_acc = 0
all_losses = []
acc_list = []

for i in range(10):
    loss = train(model, loader, optimizer, criterion) 
    all_losses.append(loss)

# %%
def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, batch in enumerate(dataloader):
            inpt = batch['embedding'].unsqueeze(1)
            predicted_label = model(inpt)
            loss = criterion(predicted_label, batch['label'])
            total_acc += (predicted_label.argmax(1) == batch['label']).sum().item()
            total_count += batch['label'].size(0)
    return total_acc / total_count

# %%
evaluate(loader)
# Out:
# 0.5132890365448505
